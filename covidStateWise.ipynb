# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("StatewiseTestingDetails.csv")

# %%
data.head()
# Out:
#          Date                        State  TotalSamples  Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0    1210.0      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0       NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0       NaN      33.0
# 3  2020-04-02               Andhra Pradesh        1800.0    1175.0     132.0
# 4  2020-04-10               Andhra Pradesh        6374.0    6009.0     365.0

# %%
data
# Out:
#            Date                        State  TotalSamples  Negative  Positive
# 0    2020-04-17  Andaman and Nicobar Islands        1403.0    1210.0      12.0
# 1    2020-04-24  Andaman and Nicobar Islands        2679.0       NaN      27.0
# 2    2020-04-27  Andaman and Nicobar Islands        2848.0       NaN      33.0
# 3    2020-04-02               Andhra Pradesh        1800.0    1175.0     132.0
# 4    2020-04-10               Andhra Pradesh        6374.0    6009.0     365.0
# 5    2020-04-11               Andhra Pradesh        6958.0    6577.0     381.0
# 6    2020-04-12               Andhra Pradesh        6958.0    6553.0     405.0
# 7    2020-04-13               Andhra Pradesh        8755.0    8323.0     432.0
# 8    2020-04-14               Andhra Pradesh       10505.0   10032.0     473.0
# 9    2020-04-15               Andhra Pradesh       11613.0   11088.0     525.0
# 10   2020-04-16               Andhra Pradesh       20235.0   19701.0     534.0
# ...

# %%
data.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
data.describe()
# Out:
#         TotalSamples       Negative     Positive
# count     556.000000     464.000000   549.000000
# mean    15160.609712   15139.693966   575.462659
# std     20414.193642   19980.628391  1038.960405
# min        58.000000       0.000000     0.000000
# 25%      2010.000000    2329.500000    32.000000
# 50%      7211.000000    7162.000000   193.000000
# 75%     19389.750000   19363.000000   572.000000
# max    120620.000000  112552.000000  8590.000000

# %%
data.isnull().sum()
# Out:
# Date              0
# State             0
# TotalSamples     52
# Negative        144
# Positive         59
# dtype: int64

# %%
sns.relplot(x="State",y="TotalSamples", data=data)

# %%
data.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
sns.relplot(y='State',x="TotalSamples",hue="Positive",data=data)

# %%
sns.relplot(x="TotalSamples",y="State",hue="Negative",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(y="Date",x="Negative",data=data)

# %%
sns.relplot(y="State",x="Positive",hue="Negative",data=data)

# %% [markdown]
# This project has done by DIVAGAR.N
#
# dated: 29/04/2020 time: 5:20pm
